# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Car Resale prediction.csv')

# %%
df.head(20)
# Out:
#     year  km_driven    fuel seller_type transmission         owner  seats  \
# 0   2014     145500  Diesel  Individual       Manual   First Owner      5
# 1   2014     120000  Diesel  Individual       Manual  Second Owner      5
# 2   2006     140000  Petrol  Individual       Manual   Third Owner      5
# 3   2010     127000  Diesel  Individual       Manual   First Owner      5
# 4   2007     120000  Petrol  Individual       Manual   First Owner      5
# 5   2017      45000  Petrol  Individual       Manual   First Owner      5
# 6   2001       5000  Petrol  Individual       Manual  Second Owner      4
# 7   2011      90000  Diesel  Individual       Manual   First Owner      5
# 8   2013     169000  Diesel  Individual       Manual   First Owner      5
# 9   2014      68000  Diesel  Individual       Manual  Second Owner      5
# 10  2005     100000  Petrol  Individual       Manual  Second Owner      5
# 11  2009     140000  Diesel  Individual       Manual  Second Owner      5
# ...

# %%
df.describe()
# Out:
#               year      km_driven        seats      mileage  engine_size  \
# count  7800.000000    7800.000000  7800.000000  7800.000000  7800.000000
# mean   2013.995385   68658.533846     5.422821    19.433287  1462.708590
# std       3.864645   47996.084516     0.962133     3.902485   504.051574
# min    1994.000000    1000.000000     4.000000     9.000000   624.000000
# 25%    2012.000000   34000.000000     5.000000    16.780000  1197.000000
# 50%    2015.000000   60000.000000     5.000000    19.300000  1248.000000
# 75%    2017.000000   96000.000000     5.000000    22.320000  1582.000000
# max    2020.000000  577414.000000    14.000000    42.000000  3604.000000
#
#        brake_horsepower  selling_price
# count       7800.000000    7800.000000
# mean          91.932424    6538.879846
# std           35.754287    8170.563106
# min           34.200000     299.990000
# 25%           69.000000    2700.000000
# 50%           82.450000    4550.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7800 entries, 0 to 7799
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              7800 non-null   int64
#  1   km_driven         7800 non-null   int64
#  2   fuel              7800 non-null   object
#  3   seller_type       7800 non-null   object
#  4   transmission      7800 non-null   object
#  5   owner             7800 non-null   object
#  6   seats             7800 non-null   int64
#  7   mileage           7800 non-null   float64
#  8   engine_size       7800 non-null   int64
#  9   brake_horsepower  7800 non-null   float64
#  10  selling_price     7800 non-null   float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 670.4+ KB

# %%
df.isnull().sum()
# Out:
# year                0
# km_driven           0
# fuel                0
# seller_type         0
# transmission        0
# owner               0
# seats               0
# mileage             0
# engine_size         0
# brake_horsepower    0
# selling_price       0
# dtype: int64

# %%
df['km_driven'].isnull().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example for a single feature
sns.boxplot(x=df['brake_horsepower'])
plt.show()

# %%
df['year'].max()
# Out:
# 2020

# %%
df.duplicated().sum()
print("Number of duplicate rows:", df.duplicated().sum())

# Remove duplicates
df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 1205

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['seller_type'], bins=10)
plt.title('Seller type')
plt.xlabel('Numerical Feature')
plt.ylabel('Frequency')
plt.show()

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       6025
# Automatic     570
# Name: count, dtype: int64

# %%
sns.scatterplot(x='km_driven', y='mileage', data=df)
plt.title('Relationship between km_driven and mileage')
plt.xlabel('km_driven')
plt.ylabel('mileage')
plt.show()

# %%
sns.boxplot(x='seats', y='selling_price', data=df)
plt.title('Numerical Feature across Categorical Feature')
plt.xlabel('seats')
plt.ylabel('selling Price')
plt.show()

# %%
numeric_df=df.select_dtypes(include=[np.number])
plt.figure(figsize=(12,8))
sns.heatmap(numeric_df.corr(),annot=True,fmt=".2f")
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2f6f6606aa2c> in <cell line: 1>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split

# Splitting the data into features (X) and target variable (y)
X = df.drop('selling_price', axis=1)  # Assuming 'SalePrice' is the column we want to predict
y = df['selling_price']

# Before encoding, let's identify the categorical variables. We assume they are of type 'object'.
categorical_cols = X.select_dtypes(include=['object']).columns

# One-hot encode the categorical features
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# Now, we split the encoded data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Let's take a look at the first few rows of our training features to confirm the changes
X_train.head()
# Out:
#       year  km_driven  seats  mileage  engine_size  brake_horsepower  \
# 6325  2008      60000      5    11.00         2993            235.00
# 1724  2018       5000      5    22.00         1197             81.80
# 2604  2017      80000      5    21.19         1396             88.73
# 3489  2014     110000      7    20.77         1248             88.76
# 4704  2017      20000      5    27.39         1248             74.00
#
#       fuel_Petrol  seller_type_Individual  transmission_Manual  \
# 6325        False                    True                False
# 1724         True                    True                 True
# 2604        False                    True                 True
# 3489        False                    True                 True
# 4704        False                    True                 True
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 6325                       False               False                 False
# ...

# %%
X_encoded
# Out:
#       year  km_driven  seats  mileage  engine_size  brake_horsepower  \
# 0     2014     145500      5    23.40         1248             74.00
# 1     2014     120000      5    21.14         1498            103.52
# 2     2006     140000      5    17.70         1497             78.00
# 3     2010     127000      5    23.00         1396             90.00
# 4     2007     120000      5    16.10         1298             88.20
# ...    ...        ...    ...      ...          ...               ...
# 7793  2013      50000      5    18.90          998             67.10
# 7794  2014      80000      5    22.54         1396             88.73
# 7795  2013     110000      5    18.50         1197             82.85
# 7796  2007     119000      5    16.80         1493            110.00
# 7797  2009     120000      5    19.30         1248             73.90
#
#       fuel_Petrol  seller_type_Individual  transmission_Manual  \
# 0           False                    True                 True
# ...

# %%
# Import the StandardScaler from sklearn.preprocessing
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and testing data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Note: It's important to fit the scaler only on the training data to avoid data leakage
X_train_scaled
# Out:
# array([[-1.42577578, -0.27075598, -0.45101555, ..., -0.62587317,
#         -0.02754497,  3.58437847],
#        [ 1.12436084, -1.41669373, -0.45101555, ..., -0.62587317,
#         -0.02754497, -0.2789884 ],
#        [ 0.86934718,  0.14594865, -0.45101555, ..., -0.62587317,
#         -0.02754497, -0.2789884 ],
#        ...,
#        [-0.40572113,  0.14594865, -0.45101555, ..., -0.62587317,
#         -0.02754497,  3.58437847],
#        [-0.40572113,  0.56265328,  1.55789795, ..., -0.62587317,
#         -0.02754497, -0.2789884 ],
#        [-1.42577578,  0.25012481, -0.45101555, ...,  1.5977678 ,
#         -0.02754497, -0.2789884 ]])

# %%
# RFE uses the top n features to build your model
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# Initialize the model
model = LinearRegression()

# Initialize RFE with the linear regression model
selector = RFE(model, n_features_to_select=5)  # Example: selecting the top 5 features

# Fit RFE
selector = selector.fit(X_train_scaled, y_train)

# Transform data based on feature selection
X_train_selected = selector.transform(X_train_scaled)
X_test_selected = selector.transform(X_test_scaled)

# %%
from sklearn.linear_model import LinearRegression

# Initialize the Linear Regression model
lr_model = LinearRegression()

# %%
lr_model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(X_test_scaled)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Calculate RMSE
rmse = np.sqrt(mse)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error: 1725.8537183977774
# Mean Squared Error: 9023607.526155174
# R-squared: 0.6871689178471952
# Root Mean Squared Error (RMSE): 3003.932010907566
